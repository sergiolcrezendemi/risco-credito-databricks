# %% [markdown]
# -- DROP CATALOG IF EXISTS credit_prod CASCADE;
#
# SELECT *
# FROM credito_prd.silver.give_me_some_credit
#
# -- DESCRIBE TABLE EXTENDED credito_prd.silver.give_me_some_credit

# %%
# %python
# %pip install xgboost
# %pip install xgboost shap
# %pip install -r ../../requirements.txt  -qqq

dbutils.library.restartPython()
