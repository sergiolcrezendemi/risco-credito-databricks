-- %%
1- criar o arquivo fazer.txt
2- criar o arquivo justificativa.md
3- criar o arquivo dicionario.md


4- avaliar desempenho do modelo
5- monitoração
6- agente para atualizar a base


7- drift, concept
